# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
vict05 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2005.xlsx")
vict06 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2006.xlsx")
vict07 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2007.xlsx")
vict08 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2008.xlsx")
vict09 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2009.xlsx")
vict10 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2010.xlsx")
vict11 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2011.xlsx")
vict12 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2012.xlsx")
vict13 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2013.xlsx")
vict14 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2014.xlsx")
vict15 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2015.xlsx")
vict16 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2016.xlsx")
vict17 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2017.xlsx")
vict18 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2018.xlsx")
vict19 = pd.read_excel("TF_ACCIDENTS_VICTIMS_2019.xlsx")
vict19.head()
# Out:
#       DT_DAY  DT_HOUR  CD_DAY_OF_WEEK TX_DAY_OF_WEEK_DESCR_FR  \
# 0 2019-09-27       17               5                Vendredi
# 1 2019-10-04       12               5                Vendredi
# 2 2019-12-30       12               1                   Lundi
# 3 2019-10-07       12               1                   Lundi
# 4 2019-09-27       17               5                Vendredi
#
#   TX_DAY_OF_WEEK_DESCR_NL  MS_VICT  MS_SLY_INJ  MS_SERLY_INJ  MS_DEAD_30_DAYS  \
# 0                 vrijdag        1           0             0                1
# 1                 vrijdag        1           1             0                0
# 2                 maandag        1           1             0                0
# 3                 maandag        1           1             0                0
# 4                 vrijdag        1           1             0                0
#
#    CD_BUILD_UP_AREA  ...      TX_ADM_DSTR_DESCR_NL CD_PROV_REFNIS  \
# ...

# %%
vict05to19 = pd.concat([vict05, vict06, vict07, 
                        vict08, vict09, vict10,
                        vict11, vict12, vict13,
                        vict14, vict15, vict16,
                        vict17, vict18, vict19],
                       ignore_index=True)
vict05to19
# Out:
#            DT_DAY  DT_HOUR  CD_DAY_OF_WEEK TX_DAY_OF_WEEK_DESCR_FR  \
# 0      2005-11-25       14               5                Vendredi
# 1      2005-10-19       21               3                Mercredi
# 2      2005-10-22       11               6                  Samedi
# 3      2005-10-18        8               2                   Mardi
# 4      2005-10-10       15               1                   Lundi
# ...           ...      ...             ...                     ...
# 843615 2019-06-15       17               6                  Samedi
# 843616 2019-06-15       17               6                  Samedi
# 843617 2019-06-15       14               6                  Samedi
# 843618 2019-06-09        3               7                Dimanche
# 843619 2019-02-07       16               4                   Jeudi
#
#        TX_DAY_OF_WEEK_DESCR_NL  MS_VICT  MS_SLY_INJ  MS_SERLY_INJ  \
# 0                      vrijdag        1           1             0
# ...

# %%
vict05to19.to_excel("vict05to19.xlsx")

# %%
vict05to19.to_hdf("vict05to19.h5", key="vict", mode='w')
# Out:
# C:\Users\mwill\anaconda3\lib\site-packages\pandas\core\generic.py:2434: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->Index(['TX_DAY_OF_WEEK_DESCR_FR', 'TX_DAY_OF_WEEK_DESCR_NL',
#        'TX_BUILD_UP_AREA_DESCR_NL', 'TX_BUILD_UP_AREA_DESCR_FR',
#        'TX_VICT_TYPE_DESCR_FR', 'TX_VICT_TYPE_DESCR_NL',
#        'TX_ROAD_USR_TYPE_DESCR_FR', 'TX_ROAD_USR_TYPE_DESCR_NL',
#        'TX_ROAD_TYPE_DESCR_FR', 'TX_ROAD_TYPE_DESCR_NL',
#        'TX_LIGHT_COND_DESCR_FR', 'TX_LIGHT_COND_DESCR_NL',
#        'TX_AGE_CLS_DESCR_FR', 'TX_AGE_CLS_DESCR_NL', 'TX_MUNTY_DESCR_FR',
#        'TX_MUNTY_DESCR_NL', 'TX_ADM_DSTR_DESCR_FR', 'TX_ADM_DSTR_DESCR_NL',
#        'TX_PROV_DESCR_FR', 'TX_PROV_DESCR_NL', 'TX_RGN_DESCR_FR',
#        'TX_RGN_DESCR_NL', 'TX_SEX_DESCR_FR', 'TX_SEX_DESCR_NL'],
#       dtype='object')]
#
#   pytables.to_hdf(
